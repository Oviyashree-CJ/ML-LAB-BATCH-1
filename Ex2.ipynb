# %%
import pandas
import numpy

arr5 = numpy.array([11,24,10,26,50,52])
pd_arr = pandas.Series(arr5)
print("Series:\n",pd_arr)
# Out:
# Series:
#  0    11
# 1    24
# 2    10
# 3    26
# 4    50
# 5    52
# dtype: int64

# %%
import pandas
import numpy

arr5 = numpy.array([11,24,10,26,50,52])
pd_arr = pandas.Series(arr5)
print("Series :\n",pd_arr)
print("Index : ",pd_arr.index)
print("Values : ",pd_arr.values)
# Out:
# Series :
#  0    11
# 1    24
# 2    10
# 3    26
# 4    50
# 5    52
# dtype: int64
# Index :  RangeIndex(start=0, stop=6, step=1)
# Values :  [11 24 10 26 50 52]

# %%
import pandas
import numpy

arr5 = numpy.array([11,24,10,26,50,52])
pd_arr = pandas.Series(arr5)
print("Series :\n",pd_arr)
print("Array : ",arr5)
print("Are they equal? ",numpy.array_equal(arr5,pd_arr))
# Out:
# Series :
#  0    11
# 1    24
# 2    10
# 3    26
# 4    50
# 5    52
# dtype: int64
# Array :  [11 24 10 26 50 52]
# Are they equal?  True

# %%
import pandas
panda_arr = pandas.Series([11,24,10,26,50,52], index = ['a','b','c','d','e','f'])
print("Series :\n",panda_arr)
# Out:
# Series :
#  a    11
# b    24
# c    10
# d    26
# e    50
# f    52
# dtype: int64

# %%
import pandas
panda_arr = pandas.Series([11,24,10,26,50,52], index = ['a','b','c','d','e','f'])
print("Series :\n",panda_arr)
print("Value at index 'c': ",panda_arr['c'])
# Out:
# Series :
#  a    11
# b    24
# c    10
# d    26
# e    50
# f    52
# dtype: int64
# Value at index 'c':  10

# %%
import pandas
info = {
    'Name' : ['Arun', 'Kala', 'Jagan', 'Tina'],
    'Age' : [18, 20, 17, 22],
    'Year' : [2, 4, 1, 4],
    'Course' : ['B.Arch', 'B.Tech', 'B.A', 'B.E']
}
data_fr = pandas.DataFrame(info)
print("Data frame: \n", data_fr)
df = data_fr.to_csv('info.csv', index="False")
print(df)
# Out:
# Data frame:
#      Name  Age  Year  Course
# 0   Arun   18     2  B.Arch
# 1   Kala   20     4  B.Tech
# 2  Jagan   17     1     B.A
# 3   Tina   22     4     B.E
# None

# %%
import pandas
data = pandas.read_csv('info.csv')
print("Data: \n", data)
# Out:
# Data:
#     Unnamed: 0   Name  Age  Year  Course
# 0           0   Arun   18     2  B.Arch
# 1           1   Kala   20     4  B.Tech
# 2           2  Jagan   17     1     B.A
# 3           3   Tina   22     4     B.E

# %%
from sklearn import datasets
data = datasets.load_iris()
df = pandas.DataFrame(data.data, columns=data.feature_names)
df['target'] = data.target
df.to_csv('sklearn_dataset.csv', index="False")
print("Data : \n",df)
# Out:
# Data :
#       sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#      target
# ...

# %%
import pandas
df = pandas.read_csv('info.csv')
print("Mean : ", df['Age'].mean())
print("Median : ", df['Age'].median())
print("Mode : \n", df['Age'].mode())
print("Variance: ", df['Age'].var())
print("Standard Deviation : ", df['Age'].std())
# Out:
# Mean :  19.25
# Median :  19.0
# Mode :
#  0    17
# 1    18
# 2    20
# 3    22
# Name: Age, dtype: int64
# Variance:  4.916666666666667
# Standard Deviation :  2.217355782608345

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder, OneHotEncoder, StandardScaler, MinMaxScaler

df = pd.read_csv("info.csv")
print("\nOriginal Data:")
print(df)
le = LabelEncoder()
df['Course_LabelEncoded'] = le.fit_transform(df['Course'])
df = pd.get_dummies(df, columns=['Course'])
print("\nAfter Encoding:")
print(df)
scaler_std = StandardScaler()
scaler_norm = MinMaxScaler()
df['Age_std'] = scaler_std.fit_transform(df[['Age']])
df['Year_std'] = scaler_std.fit_transform(df[['Year']])
df['Age_norm'] = scaler_norm.fit_transform(df[['Age']])
df['Year_norm'] = scaler_norm.fit_transform(df[['Year']])
print("\nAfter Scaling:")
print(df)
df_final = df.drop(['Name'], axis=1)
print("\nFinal Preprocessed Dataset:")
print(df_final)
# Out:
# Original Data:
#    Unnamed: 0   Name  Age  Year  Course
# 0           0   Arun   18     2  B.Arch
# 1           1   Kala   20     4  B.Tech
# 2           2  Jagan   17     1     B.A
# 3           3   Tina   22     4     B.E
#
# After Encoding:
#    Unnamed: 0   Name  Age  Year  Course_LabelEncoded  Course_B.A  \
# 0           0   Arun   18     2                    1       False
# 1           1   Kala   20     4                    3       False
# 2           2  Jagan   17     1                    0        True
# 3           3   Tina   22     4                    2       False
#
#    Course_B.Arch  Course_B.E  Course_B.Tech
# 0           True       False          False
# 1          False       False           True
# 2          False       False          False
# 3          False        True          False
#
# After Scaling:
#    Unnamed: 0   Name  Age  Year  Course_LabelEncoded  Course_B.A  \
# 0           0   Arun   18     2                    1       False
# ...

# %%
import pandas as pd

df = pd.DataFrame(info)

# Filtering student with age greater than 18 and studying in 4th year
filtered_df = df[(df['Age'] > 18) & (df['Year'] == 4)]
print("Filtered Data (Age > 18 and Year == 4):")
print(filtered_df)
# Out:
# Filtered Data (Age > 18 and Year == 4):
#    Name  Age  Year  Course
# 1  Kala   20     4  B.Tech
# 3  Tina   22     4     B.E

# %%
import pandas as pd

df1 = pd.DataFrame(info)
extra_info = {
    'Name': ['Jagan', 'Tina', 'Arun'],
    'GPA': [8.2, 9.1, 7.5]
}
df2 = pd.DataFrame(extra_info)
merged_df = pd.merge(df1, df2, on='Name', how='left')
print("Merged DataFrame:")
print(merged_df)
# Out:
# Merged DataFrame:
#     Name  Age  Year  Course  GPA
# 0   Arun   18     2  B.Arch  7.5
# 1   Kala   20     4  B.Tech  NaN
# 2  Jagan   17     1     B.A  8.2
# 3   Tina   22     4     B.E  9.1

# %%
import pandas as pd
import numpy as np
info = {
    'Name': ['Arun', 'Kala', 'Jagan', 'Tina'],
    'Age': [18, np.nan, 17, 22],
    'Year': [2, 4, 1, np.nan],
    'Course': ['B.Arch', 'B.Tech', 'B.A', 'B.E']
}
df = pd.DataFrame(info)
df['Age'] = df['Age'].fillna(df['Age'].mean())
df['Year'] = df['Year'].fillna(df['Year'].mode()[0])

print("Dataframe after handling missing values:")
print(df)
# Out:
# Dataframe after handling missing values:
#     Name   Age  Year  Course
# 0   Arun  18.0   2.0  B.Arch
# 1   Kala  19.0   4.0  B.Tech
# 2  Jagan  17.0   1.0     B.A
# 3   Tina  22.0   1.0     B.E

# %%
import pandas as pd
from sklearn.preprocessing import MinMaxScaler

info = {
    'Name': ['Arun', 'Kala', 'Jagan', 'Tina'],
    'Age': [18, 20, 17, 22],
    'Year': [2, 4, 1, 4],
    'Course': ['B.Arch', 'B.Tech', 'B.A', 'B.E']
}
df = pd.DataFrame(info)
scaler = MinMaxScaler()
df[['Age_norm', 'Year_norm']] = scaler.fit_transform(df[['Age', 'Year']])

print("DataFrame after Min-Max Normalization:")
print(df[['Name', 'Age', 'Age_norm', 'Year', 'Year_norm']])
# Out:
# DataFrame after Min-Max Normalization:
#     Name  Age  Age_norm  Year  Year_norm
# 0   Arun   18       0.2     2   0.333333
# 1   Kala   20       0.6     4   1.000000
# 2  Jagan   17       0.0     1   0.000000
# 3   Tina   22       1.0     4   1.000000

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
iris = load_iris()
X = iris.data
y = iris.target
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X_scaled)
plt.figure(figsize=(8,6))
for label in np.unique(y):
    plt.scatter(X_pca[y == label, 0], X_pca[y == label, 1], label=iris.target_names[label])

plt.title("PCA: Iris Dataset Dimensionality Reduction")
plt.xlabel("Principal Component 1")
plt.ylabel("Principal Component 2")
plt.legend()
plt.grid(True)
plt.show()
